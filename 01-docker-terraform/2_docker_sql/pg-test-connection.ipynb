# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# ```bash
# pip install sqlalchemy psycopg2-binary
# ```

# %%
# !pip install sqlalchemy psycopg2-binary

# %%
engine = create_engine('postgresql://admin:password@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
# # a = pd.read_sql("SELECT * FROM example_table LIMIT 0", engine)
# a.columns

# %%
path="/mnt/c/Users/USER/Desktop/data-engineering-zoomcamp/taxi+_zone_lookup.csv"
df_csv = pd.read_csv(path)
table_name = "trip_zone"
df_csv.head(0).to_sql(table_name, engine, if_exists='replace', index=False)
df_csv.to_sql(table_name, engine, if_exists='append', index=False)
# Out:
# 263

# %%
# read parquet fil

parquet_path = "/mnt/c/Users/USER/Desktop/data-engineering-zoomcamp/Testing/yellow_tripdata_2021-01.parquet"
df_par = pd.read_parquet(parquet_path, engine='pyarrow')
# Out:
# 1369769

# %%
table_name = "yellow_trip_data"
df_par.head(0).to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# 0

# %%
df_par.columns
df_par['tpep_pickup_datetime'] = pd.to_datetime(df_par['tpep_pickup_datetime'])
df_par['tpep_dropoff_datetime'] = pd.to_datetime(df_par['tpep_dropoff_datetime'])

# %%
print(pd.io.sql.get_schema(df_par, table_name, con=engine))
# print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_trip_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df_par.to_sql(table_name, engine, if_exists='append', index=False, chunksize=10000, 
              )
# Out:
# 136769

# %%
query = """
SELECT 1 as number;
"""

pd.read_sql(query, con=engine)
# Out:
#    number
# 0       1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname             tablename tableowner tablespace  hasindexes  \
# 0     public  yellow_tripdata_trip       root       None       False
#
#    hasrules  hastriggers  rowsecurity
# 0     False        False        False

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
few = pd.read_csv("/mnt/c/Users/USER/Desktop/data-engineering-zoomcamp/Testing/output.csv.gz",iterator=True, chunksize=100000)

# %%
next(few)
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1             2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2             2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3             2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4             2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-09-08 21:34:31   2019-09-08 21:42:44                  N
# 99996         2  2019-09-08 21:06:54   2019-09-08 21:12:38                  N
# 99997         2  2019-09-08 21:22:10   2019-09-08 21:29:33                  N
# 99998         2  2019-09-08 21:33:42   2019-09-08 21:33:48                  N
# 99999         2  2019-09-08 21:29:16   2019-09-08 21:36:45                  N
#
# ...

# %%
df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)

# %%
query = """
SELECT * FROM yellow_tripdata_trip LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30                1
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34                1
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13                1
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# ...

# %% [markdown]
# ```sql
# SELECT *
# FROM pg_catalog.pg_tables
# WHERE schemaname != 'pg_catalog' AND
#     schemaname != 'information_schema';
# ```
#
# Source: https://www.postgresqltutorial.com/postgresql-show-tables/
